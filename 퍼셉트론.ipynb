# %% [markdown]
# <a href="https://colab.research.google.com/github/shjiinn/E-Learning/blob/master/%ED%8D%BC%EC%85%89%ED%8A%B8%EB%A1%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 퍼셉트론

# %% [markdown]
# 1. 퍼셉트론의 구조
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -

# %% [markdown]
# - 각 입력값과 각 가중치를 곱하여 합한 값을 활성화 함수에 보냄
#   - 그 활성화 함수에서 그 값이 임곗값보다 크면 1이 출력
#   - 임곗값보다 작으면 -1을 출력
# - 퍼셉트론 알고리즘 : 이 출력을 우리가 원하는 값과 비교해서 오차가 있으면, 이를 반영해서 가중치를 변경

# %% [markdown]
# 2. 순입력 계산과정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. 퍼셉트론 이진 분류
# - 선형 이진 분류기(linear binary classifier)
#   - 2차원에서 직선으로 분류 가능하다고 전제
#   - 필요한 요소
#     - 입력
#     - 가중치
#     - 활성화 함수
#       - 시그모이드 함수
#       - 계단함수
#       - 쌍곡탄젠트 함수
#       - 렐루(ReLU) 함수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. 퍼셉트론의 학습방법
#   - 학습 - 가중치의 변화
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. 과대적합과 과소적합
# - 완벽한 퍼셉트론?
#   - 실제로는 어려움
#   - 경계선 상에 데이터가 많을 수록 새로운 데이터를 잘 분류하지 못하는 경우가 종종 생김
#
# - 과대적합 : 학습자료 자체만 완벽하게 분류하려고 할 때 발생
# - 과소적합 : 오차를 너무 허용할 때 발생

# %% [markdown]
# ### 퍼셉트론 알고리즘

# %% [markdown]
# 1. 퍼셉트론 알고리즘
#   - 목적 : 입력 x를 분류하는 가중치 w 구하기
#   - 알고리즘 요약
#     - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 퍼셉트론 코딩

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
x=np.array([[2,2],[3,3],[1.5,0]])
x
X=np.c_[np.ones(len(x)),x]
X
# Out:
# array([[1. , 2. , 2. ],
#        [1. , 3. , 3. ],
#        [1. , 1.5, 0. ]])

# %% [markdown]
# - maxlabel, minlabel을 분리한 이유는 -1과 1사이의 값이 출력되더라도 코딩을 수정할 필요가 없기 때문

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - plot_xyz(x,y,W, annotate=True)
#   - annotate : 수치 데이터 표시
#   - np.vstack : Numpy 결합
